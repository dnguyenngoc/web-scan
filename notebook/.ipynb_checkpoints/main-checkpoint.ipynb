# %%
import os
os.chdir('./')
from serve_model import *
import json
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
cmnd = read_image_from_dir('./test_image/test_5.jpg')
prediction = predict_cmnd(cmnd)
plt.imshow(cmnd)
plt.show()
print(prediction)


image = read_image_from_dir('./test_image/giay_ra_vien.jpg')
prediction = predict_giay_ra_vien(image)
plt.imshow(image)
plt.show()
print(prediction)
# Out:
# predicted time:  1.2178664207458496
# {'id': '168609178', 'name': 'HOÀNG MANH TUẤN', 'birth': 'BOTFB VIET.TK', 'home': '47 Đường Số KP6 2 Bình Hưng Hòa Q Bình Tân', 'add': 'TP Hồ Chí Minh'}
# {'name': 'TRẦN QUANG HIẾU', 'birth': '44 Tháng', 'sex': 'Nam', 'nation': 'Kinh', 'country_boxes': 'Việt Nam', 'id': 'TE1393923639319', 'add': 'Xóm 1 - Xã Thiệu Phúc - Huyện Thiệu Hóa - Thanh Hóa', 'come_time': '08 giờ 00 phút, ngày 11 tháng 3 năm 2011', 'out_time': '10 giờ 00 phút, ngày 11 tháng 3 năm 2011', 'diagnostic': 'J18 - viêm phổi cấp', 'solution': 'hạ sôt, kháng sinh, kháng viêm, giảm ho, long đờm, trợ lực', 'note': 'Nghĩ ngơi, ăn uống bồi dưỡng'}
