# %%
import os
os.chdir('/home/pot/Desktop/web-scan')
from merged_model import CompletedModel
from ai_service import *
from helpers import ocr_helpers

# %%
# LOAD IMAGE TEST
img = ocr_helpers.read_image_from_dir(r'/home/pot/Desktop/web-scan/test_data/discharge_record/0.jpg')
img = np.asarray(img)

model =CompletedModel()

# %%
# %matplotlib inline
crop_image = model.get_corner_of_discharge_record(img)

ocr_helpers.implt(crop_image)

# %%
print(model.predict_giay_ra_vien(crop_image))
# Out:
# /home/pot/Desktop/web-scan/merged_model.py:199: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   result = self.text_recognition_model.predict_on_batch(np.array(list_ans))
# {'name': 'TRẦN QUANG HIẾU', 'age': '44 Tháng', 'gender': 'i tính: Nam', 'nation': 'Kinh', 'country': 'Việt Nam', 'insurance_no': 'TE 138 38 236', 'address': 'Thuật chỉ: xóm 1 - Xã Thiệu Phúc - Huyện Thiệu Hoá - Thanh Hóa', 'admission_date': '03800000038', 'discharge_date': '08 giờ 00 phát, ngày 01 tháng 03 năm 2021', 'diagnostic': 'nều tri. ba sột kháng sinh kháng viêm siêm họ long đêm tra lưa', 'solution': 'ngơi ăn uống bồi dưỡng', 'note': 'tháp điều trì, hạ sốt, kháng sinh, kháng viêm, giảm ho, long đờm, trợ', 'job': 'dưới 6 tuổi'}
